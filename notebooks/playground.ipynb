# %%
from whispercpp import Whisper
# Out:
# Saving models to: /Users/bmoreno/.ggml-models

# %%
# Out:
# whisper_init_from_file_no_state: loading model from '/Users/bmoreno/.ggml-models/ggml-tiny.bin'
# whisper_model_load: loading model
# whisper_model_load: n_vocab       = 51865
# whisper_model_load: n_audio_ctx   = 1500
# whisper_model_load: n_audio_state = 384
# whisper_model_load: n_audio_head  = 6
# whisper_model_load: n_audio_layer = 4
# whisper_model_load: n_text_ctx    = 448
# whisper_model_load: n_text_state  = 384
# whisper_model_load: n_text_head   = 6
# whisper_model_load: n_text_layer  = 4
# whisper_model_load: n_mels        = 80
# whisper_model_load: f16           = 1
# whisper_model_load: type          = 1
# whisper_model_load: mem required  =  129.00 MB (+    3.00 MB per decoder)
# whisper_model_load: adding 1608 extra tokens
# whisper_model_load: model ctx     =   73.58 MB
# whisper_model_load: model size    =   73.54 MB
# whisper_init_state: kv self size  =    2.62 MB
# whisper_init_state: kv cross size =    8.79 MB
# Loading data..
# ...

# %%
# !cat ../audio/jfk.mp3
# Out:
# +;V?TXXXSoftwareLavf59.27.100���Xing4*h "&)+.03579;=>ABDFHJOTWZ\]`fikmnprtvxz|��������������������������������������������������PLAME3.100P$@!�*h"����x�x@��������������o')���>�#���������sY��Z3�[�:N��G92"2IѶWj�e���]�TgI�Ov�'I,�.�Bg]��eI��/�W�Z�F�I���� ��?�����H�k�>y�N2DϤk��ؕ���
# ����8<��NLD�b��?���	�OZ�fxd�*�/51?����?���.��p�
# ߧ����v���j@�/���(��|D@C2����?���饖i�G��,0ː�JH, 	-��-s��7����%2N�@��]����R�:]����B�H���Шh��.C�*����y�<�j�c�
# �sw�7�,A5 ɛݷ~�3P�`2��".�Yh]t5���'�hS��-5��ImF��ڑw*f��P2��X��(#�|��m>�)_	�B�HY��X�8�p�.��sНˆm+Z���V��w��2�J��V�������K\�U��.MȎ��N.�痻�E���eNubq�;������;7��d��|V�׽�?w�TfvG���Z/;)�M~1OZ�Y/�A��*�j�,�Z[��w)��ĺ������w;�k�=�Ƭ�_�$�W>��T���۱n��ʰ���,o�/���5��
# $�ˠ�F�lM�ǋ�r��1v��.��V�R;�����:
# ʱ��O����Fp���&h�5)$�� �cQΗ�u���4͏ca�3��j����lE#��-+I������X��(T��y�U�9��5��R;j̑�}��F�=��: �����<�r�������6<E���������y0�X~�}���
# �v��ߩRè�Q�9I-�Vc�F0z��F��1�����z��7y<����fcP,�Լy��X��(Cy�u,��g�X�n�r�[�!��̔1��wg����ԋ�c�o/5v�f[�v����Č�H�Ď�Ϥ{~�b�)����3َ� ���Rh��Dܱ��@�\�|�X�
# ...
